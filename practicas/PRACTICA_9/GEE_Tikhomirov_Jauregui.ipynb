# %% [markdown]
# <div style="border: 3px solid #0074D9; border-radius: 15px; background: linear-gradient(135deg, #eaf3ff, #d6e6ff); padding: 25px; text-align: center; box-shadow: 0px 0px 12px rgba(0,0,0,0.1); margin-top: 20px;">
#
#   <h3 style="color:#004080; font-family:'Segoe UI', sans-serif; margin-bottom: 10px;">
#     Dr. Jesús Martí Gavilá
#   </h3>
#   <p style="font-size:16px; color:#004080; margin-top: 0;text-align: center">
#     Departamento de Ingeniería Cartográfica, Geodesia y Fotogrametría
#   </p>
#
#   <hr style="width:60%; border:1px solid #0074D9; margin:20px auto;">
#
#   <h1 style="color:#003366; font-family:'Trebuchet MS', sans-serif; font-size:40px; margin-bottom: 5px;">
#     PRÁCTICA 9
#   </h1>
#   <h2 style="color:#004d99; font-family:'Trebuchet MS', sans-serif; font-size:24px; margin-top: 0;">
#     GOOGLE EARTH ENGINE PARA PYTHON
#   </h2>
#
#   <div style="text-align: center; margin: 20px 0;">
#     <a href="http://www.upv.es/titulaciones/GTI/indexc.html" target="_blank">
#       <img src="https://www.upv.es/entidades/epsg/wp-content/themes/upv/assets/upv_logo.svg" width="180" style="border:none;">
#     </a>
#
#   </div>
#
#   <h3 style="color:#003366; font-family:'Segoe UI', sans-serif; margin-top: 10px;">
#     Grado en Tecnologías Interactivas | Tecnologías de la Información Geográfica
#   </h3>
# </div>

# %% [markdown]
# <div style="border: 2px solid #0074D9; border-radius: 12px; background: linear-gradient(135deg, #eaf3ff, #d6e6ff); padding: 20px; text-align: center; box-shadow: 1px 1px 6px rgba(0,0,0,0.1); margin-top: 25px;">
#   <h2 style="color:#003366; font-family:'Trebuchet MS', sans-serif;">Datos del alumno</h2>
#   <hr style="width:50%; border:1px solid #0074D9; margin-bottom:20px;">
#   <p style="font-size:18px; color:#004d99; font-family:'Segoe UI', sans-serif;">
#     <b>Nombre y Apellidos:</b> <span style="border-bottom:1px dotted #004d99;">&nbsp;&nbsp;&nbsp;Fedor Tikhomirov y Adrián Jáuregui Felipe&nbsp;&nbsp;&nbsp;</span>
#   </p>
#   <p style="font-size:18px; color:#004d99; font-family:'Segoe UI', sans-serif;">
#     <b>Fecha:</b> <span style="border-bottom:1px dotted #004d99;">&nbsp;&nbsp;&nbsp;02/12/2025 &nbsp;&nbsp;&nbsp;</span>
#   </p>
# </div>

# %% [markdown]
# <font size = 6 color="red" >Enunciado </font>
# <div><b>Google Earth Engine</b>  <div align="justify">Es una plataforma de geomática basada en la nube, con un catálogo de varios petabytes de imágenes satélites y conjuntos de datos geoespaciales, que permite a los usuarios visualizar y analizar de forma interactiva, cambios en la superficie del planeta mediante imágenes de satélite. Los científicos y las organizaciones sin ánimo de lucro utilizan Google Earth Engine para llevar a cabo estudios de teledetección remota, predecir brotes de enfermedades, gestionar recursos naturales, etc. Los estudiantes pueden acceder a esta información para participar en los debates y convertirse en científicos de datos.</div>
# <h2>Tabla de Contenido</h2>
#     <ul>
#         <li>
#             Librerias y activación Google Earth Engine
#         </li>
#         <li>
#             Mapa Indice de Severidad Normalizado (dNBR)
#         </li>
#         <li>
#             Mapa Dual
#         </li>
#         <li>
#             Tareas a realizar:
#                <ul type ='1'>
#                    <li> 1. Calcular índice SAVI </li>
#                    <li> 2. Calcular índice EVI </li>
#                    <li> 3. Mapa Dual </li>
#             </ul>
#         </li>
#     </ul>
# <p>

# %% [markdown]
# <font size = 6 color="red" >Objetivos</font>
# <ul>
#    <li>Configurar las librerías necesarias y activar Google Earth Engine en Python.</li>
#     <li>Calcular el Índice de Severidad Normalizado (dNBR).</li>
#     <li>Calcular el índice SAVI.</li>
#     <li>Calcular el índice EVI.</li>
#     <li>Realizar un mapa dual para comparar los resultados.</li>
# </ul>

# %% [markdown]
# <font size = 6 color="red" >Entrega</font><p>
# # TAREA 1
# Realizar un mapa del Índice de Vegetación Ajustado al Suelo (SAVI) con imágenes SENTINEL 2A, analizando la evolución del incendio en Montixelvo (2/11/2023).
# <ul>
#     <li>Parámetros de localización:</li>
#     <ul>
#     <li>Fechas Pre: '2023-09-15', '2023-10-15'</li>
#     <li>Fechas Post: '2023-11-15', '2023-12-15'</li>
#     <li>Zona Para Exportar: Punto mínimo: [38.8, -0.4] Punto máximo [39.0, -0.15]</li>
#     <li>Punto Central: [38.9, -0.28]</li>
#     </ul>
#     <li>Calcular el SAVI_pre, SAVI_post y Guardar SAVI_post como Geotiff </li>
# </ul>
#
# # TAREA 2
# Crear un mapa del Índice de Vegetación Mejorado (EVI) con imágenes LANDSAT 8 para la evolución del mismo incendio.
# <ul>
#    <li>Calcular el EVI_pre, EVI_post y Guardar EVI_post como Geotiff</li>
# </ul>
#
# # TAREA 3
# Realizar un mapa dual con los mapas obtenidos en la Tarea 1 y 2<p>
# <ul><li>Salvar el mapa como:  Medio_Ambiente_'Apellidos alumnos'.html</li></ul>

# %% [markdown]
# <font size = 6 color="red" >Recursos</font>
# <p>
# <b> Ejemplos: </b> <p>
# <a href = 'https://github.com/google/earthengine-api'> https://github.com/google/earthengine-api</a> <p>
# <a href = 'https://github.com/gee-community/qgis-earthengine-plugin/tree/master/examples'>https://github.com/gee-community/qgis-earthengine-plugin/tree/master/examples</a><p>
# <a href = 'https://github.com/giswqs/Awesome-GEE#python-api'> https://github.com/giswqs/Awesome-GEE#python-api</a><p>
#
# <b> Documentación: </b><p>
# <a href = 'https://python-visualization.github.io/folium'>https://python-visualization.github.io/folium</a><p>
# <a href = 'https://developers.google.com/earth-engine/guides'>https://developers.google.com/earth-engine/guides</a>
# </div>

# %% [markdown]
# ### <font color="blue" >Catálogo de recursos GEE </font>
# Enlace al catálogo de datos ofical de GEE<p>
# <a href = 'https://developers.google.com/earth-engine/datasets'>https://developers.google.com/earth-engine/datasets</a>

# %% [markdown]
# <div style="border: 3px solid #0074D9; border-radius: 12px; background: linear-gradient(135deg, #eaf3ff, #d6e6ff); padding: 20px; text-align: center; box-shadow: 2px 2px 8px rgba(0,0,0,0.15); margin-top: 25px;">
#   <h1 style="color:#003366; font-family:'Trebuchet MS', sans-serif; font-size:36px;">PRACTICA 9</h1>
#   <hr style="width:60%; border:1px solid #0074D9;">
#   <h3 style="color:#004d99;">Inicio de la resolución</h3>
# </div>

# %% [markdown]
# <h1 align=center><font color="green" >Estudio de Indices de Vegetación con Google Earth Engine.</font></h1><p>
#
# <h2 align=center> Casos de estudios </h2><p>
# <h4 align=center> <em>Crear mapas de diferentes índices de vegetación del incendio ocurrido en la zona de Montixelvo el 2/11/2023 </em> <p>
# --------------------------------------------------------------------------------------------------------------------------------------------------------</h4>

# %% [markdown]
# <div align="justify"> La vegetación constituye uno de los componentes del medio físico de la mayor importancia para el equilibrio del medio ambiente. Por un lado, se trata de un recurso con un valor intrínseco (agricultura, pastos, bosques). Por otro lado, la cubierta vegetal juega un papel decisivo para el adecuado mantenimiento de otros muchos recursos (fauna, suelos, paisaje).
# Mediante el análisis multitemporal de imágenes de satélite, es posible hacer un seguimiento de la evolución de las diferentes comunidades vegetales y de los cultivos agrícolas. Los Índices de Vegetación son combinaciones de las bandas espectrales registradas por los satélites de Teledetección, cuya función es realzar la cubierta vegetal en función de su respuesta espectral y atenuar los detalles de otros componentes como el suelo, la iluminación, etc.
# Los Índices de Vegetación, son pues imágenes calculadas a partir de operaciones algebraicas entre distintas bandas espectrales. El resultado permite obtener una nueva imagen donde se destacan gráficamente determinados píxeles relacionados con parámetros de las coberturas vegetales: densidad, índice de área foliar y actividad clorofílica. (MappingGis)</div>

# %% [markdown]
# ### Previamente asegurarse de tener instaladoas las librerias earthengine-api y folium en el enviroment de trabajo

# %% [markdown]
# <h2><font color="blue" >Librerías y Activación GEE</font></h2><p>
#
# Cargar las librerías necesarias y activar la plataforma de GEE en la que previamente el usuario deberá haberse registrado.

# %%
import folium
from folium import plugins
import ee
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8BU_gF9TLSbjExU3JdMu_wZdTOs4rJJgn7gfgMNc2nY&tc=u6BvN8e5LIyc6hS5Pa7H-PuzpZr50ETLdpxX9Y04MvU&cc=Owcc8Szdn7_eIhGOw3rKX0WoZFI-FvZJ4qc_BECz5EE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=8BU_gF9TLSbjExU3JdMu_wZdTOs4rJJgn7gfgMNc2nY&tc=u6BvN8e5LIyc6hS5Pa7H-PuzpZr50ETLdpxX9Y04MvU&cc=Owcc8Szdn7_eIhGOw3rKX0WoZFI-FvZJ4qc_BECz5EE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1Ab32j91993M5lxsB_R20vaoRa_JowoIk8djH9XRKdBhhUQFpQtF7HxJzlA8
# Successfully saved authorization token.

# %%
# Función de EE predefinida para añadir capas con Folium

def add_ee_layer (self, ee_imagen, parametros, nombre):
    map_id = ee.Image(ee_imagen).getMapId(parametros)
    folium.raster_layers.TileLayer(
        tiles=map_id['tile_fetcher'].url_format, 
        attr = 'Alumno: Tecnologías de la Información Geográfica',
        name = nombre,
        overlay = True, # Permite la superposición
        control = True # Permite que aparezca la capa o no en el layer control
        ).add_to(self)

# Con esto creamos un método propio llamado addLayer que llamara a la función add_ee_layer
folium.Map.addLayer = add_ee_layer

# %% [markdown]
# <h2><font color="blue" >Mapa Indice de Severidad Normalizado dNBR</font></h2><p>
#
# <h3>Indice Normalizado de Área Quemada (NBR)</h3> <div align="justify"> Es un índice diseñado para resaltar áreas quemadas en grandes zonas de incendio. Para calcularlo se utilizan imágenes satélites multiespectrales que indican el contenido de celulosa de la Vegetación y el contenido de agua en el suelo y la vegetación. Para este fin se usarán imágenes del Sentinel 2, una misión del programa Copernicus de la ESA. El índice combina dos bandas espectrales: el infrarrojo próximo, (banda B8A - 865 nm) y el infrarrojo de onda corta o medio (banda 12 – 2190 nm), los cuales son sensibles a la celulosa y al contenido de agua, respectivamente. El índice NBR mostrará una relación de valores comprendidos entre -1 y 1, donde los valores negativos ilustran zonas afectadas por el fuego mientras que valores positivos representan zonas vegetales sanas o en fase de regeneración si se han visto afectadas por el incendio.</div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <h3>Ejemplo de Indice Normalizado de Área Quemada (NBR) en la zona de Marxuquera (Gandia) incendio Agosto 2018</h3>

# %%
# Colección de imágenes de Sentinel con una nubosidad inferior al 20% y la medía calculada de los pixels
sentinel_pre= (ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
                  .filterDate('2018-07-03', '2018-08-03')
                  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',20)).mean()) #el filtro de nubosidad varía según imagen

sentinel_post= (ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
                  .filterDate('2018-08-15', '2018-09-15')
                  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',20)).mean())

# Funciones de calculo NBR
def NBR(image):
    NBR = image.expression('float(NIR-SWIR2)/(NIR+SWIR2)',{
        'NIR' : image.select("B8").multiply(0.0001),     # Escala según el catalogo de datos de GEE para sentinel2
        'SWIR2' : image.select("B12").multiply(0.0001),
    })
    return NBR

# Parámetros de visualización de la imágen
vis_NBR ={
    'max': 1,
    'min': -0.1,
    # Paleta de colores standar de GEE
    'palette' : ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718','74A901', '66A000', '529400', '3E8601', '207401', '056201',
               '004C00', '023B01', '012E01', '011D01', '011301']} 

# Llamada a las funciones
NBR_pre = NBR(sentinel_pre)
NBR_post = NBR(sentinel_post)


# Exportar imagen a Google Drive. Configuración parámetros de salida
geometry = ee.Geometry.Rectangle([-0.40, 38.9, -0.20, 39.1]) # Coordenadas geográficas minima (longitud, latitud) y maxima de la imagen a exportar
task_config = {
        'region': geometry,
        'fileFormat': 'GeoTIFF',
        'fileNamePrefix': 'Marti_NBR_post',
        'folder':'gee-datos',
        'scale': 20,      # Resolución en metros del pixel, siempre la resolución más desfavorable de las bandas utilizadas 
        'crs': 'EPSG:4326',
        'image': NBR_post,
        'description': 'Imagen procesada NBRpost'
    }
ee.batch.Export.image.toDrive(**task_config).start()

# Crear y añadir elementos al mapa
mapa_NBR = folium.Map(location=[38.9,-0.30], zoom_start = 11) #Las coordenadas son en Latitud y Longitud
mapa_NBR.addLayer(NBR_pre,vis_NBR, "NBR_pre")
mapa_NBR.addLayer(NBR_post,vis_NBR, "NBR_post")

folium.LayerControl().add_to(mapa_NBR)

mapa_NBR
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a06d0b3fb17ee24cf54be7e7645fed8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a06d0b3fb17ee24cf54be7e7645fed8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a06d0b3fb17ee24cf54be7e7645fed8 = L.map(
#                 &quot;map_8a06d0b3fb17ee24cf54be7e7645fed8&quot;,
#                 {
#                     center: [38.9, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34568658a96f2a204bff08aa6b72d37a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_34568658a96f2a204bff08aa6b72d37a.addTo(map_8a06d0b3fb17ee24cf54be7e7645fed8);
#
#
#             var tile_layer_7dff20ab96b0b800d38f6c32cab19587 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/0a415424a087273433c47f071912b8d1-aa766006f793a2cfef219f721f9fc573/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7dff20ab96b0b800d38f6c32cab19587.addTo(map_8a06d0b3fb17ee24cf54be7e7645fed8);
#
#
#             var tile_layer_14d50e5d25ac14c1e9abc1b3f4bff12c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/373854ec40529730a94fff86b0834d9b-f9ab76a9d033e3a3a491a6d0e4650c99/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_14d50e5d25ac14c1e9abc1b3f4bff12c.addTo(map_8a06d0b3fb17ee24cf54be7e7645fed8);
#
#
#             var layer_control_7778f509f5e4c1ab362725cb03e61a39_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_34568658a96f2a204bff08aa6b72d37a,
#                 },
#                 overlays :  {
#                     &quot;NBR_pre&quot; : tile_layer_7dff20ab96b0b800d38f6c32cab19587,
#                     &quot;NBR_post&quot; : tile_layer_14d50e5d25ac14c1e9abc1b3f4bff12c,
#                 },
#             };
#             let layer_control_7778f509f5e4c1ab362725cb03e61a39 = L.control.layers(
#                 layer_control_7778f509f5e4c1ab362725cb03e61a39_layers.base_layers,
#                 layer_control_7778f509f5e4c1ab362725cb03e61a39_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_8a06d0b3fb17ee24cf54be7e7645fed8);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3>Indice de Severidad Normalizado (dNBR)</h3><div align="justify">  Es un índice normalizado que indica la pérdida de masa orgánica. La diferencia entre el NBR previo y posterior al incendio, obtenido de las imágenes satélite, se usa para calcular el diferencial NBR , con el que estimar la severidad del incendio. Un valor más alto de dNBR indica un daño más severo, mientras que las áreas con valores negativos de dNBR indican un creci-miento después de un incendio. </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Funciones de calculo dNBR
def dNBR(pre,post):
    dNBR = pre.subtract(post).multiply(1000) 
    return dNBR 

# Parámetros de visualización de la imágen
vis_dNBR ={
    'max': 1000,
    'min': 100,
    # Paleta de colores standar de GEE
    'palette' : ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718','74A901', '66A000', '529400', '3E8601', '207401', '056201',
               '004C00', '023B01', '012E01', '011D01', '011301']} 
# Llamada a la funcion
imagen_dNBR= dNBR(NBR_pre,NBR_post)


mapa_dNBR = folium.Map(location=[39,-0.30], zoom_start = 12)
mapa_dNBR.addLayer(imagen_dNBR,vis_dNBR, "dNBR")
folium.LayerControl().add_to(mapa_dNBR)

mapa_dNBR
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a265d1a06828afa881fdecda1ab95ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a265d1a06828afa881fdecda1ab95ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a265d1a06828afa881fdecda1ab95ad = L.map(
#                 &quot;map_6a265d1a06828afa881fdecda1ab95ad&quot;,
#                 {
#                     center: [39.0, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da6b260576103efbaaa27688f8661010 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_da6b260576103efbaaa27688f8661010.addTo(map_6a265d1a06828afa881fdecda1ab95ad);
#
#
#             var tile_layer_11bf8a0e057e262a74f5b660c9053a71 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/0be5ff0d87cbebeb8d4b68064a255dcd-2ae269cf943195eaff2c6ff0a14b821f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_11bf8a0e057e262a74f5b660c9053a71.addTo(map_6a265d1a06828afa881fdecda1ab95ad);
#
#
#             var layer_control_a442f17fbb4ddd674fd1bc26fa9d9674_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_da6b260576103efbaaa27688f8661010,
#                 },
#                 overlays :  {
#                     &quot;dNBR&quot; : tile_layer_11bf8a0e057e262a74f5b660c9053a71,
#                 },
#             };
#             let layer_control_a442f17fbb4ddd674fd1bc26fa9d9674 = L.control.layers(
#                 layer_control_a442f17fbb4ddd674fd1bc26fa9d9674_layers.base_layers,
#                 layer_control_a442f17fbb4ddd674fd1bc26fa9d9674_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6a265d1a06828afa881fdecda1ab95ad);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ![Severidad.JPG](attachment:Severidad.JPG)

# %%
import branca
# Ejemplo aplicación de intervalos a imagenes.
sld_intervalos = """
    <RasterSymbolizer>
        <ColorMap type="intervals" extended="false" >
            <ColorMapEntry color="#ffffff" quantity="100" label="Zonas No quemado"/>
            <ColorMapEntry color="#00ff00" quantity="270" label="Gravedad baja" />
            <ColorMapEntry color="#007f30" quantity="440" label="Gravedad Media baja" />
            <ColorMapEntry color="#FFA500" quantity="660" label="Gravedad Media Alta" />
            <ColorMapEntry color="#ff0000" quantity="1000" label="Gravedad Alta" />
        </ColorMap>
    </RasterSymbolizer>"""

# Leyenda
legend_html = """
{% macro html(this, kwargs) %}
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 250px;
    height: 250px;
    z-index:9999;
    font-size:14px;
    ">
    <p><a style="color:#ffffff;font-size:150%;margin-left:20px;">◼</a>&emsp;Zonas No quemado
    <p><a style="color:#00ff00;font-size:150%;margin-left:20px;">◼</a>&emsp;Gravedad baja
    <p><a style="color:#007f30;font-size:150%;margin-left:20px;">◼</a>&emsp;Gravedad media baja
    <p><a style="color:#FFA500;font-size:150%;margin-left:20px;">◼</a>&emsp;Gravedad media Alta
    <p><a style="color:#ff0000;font-size:150%;margin-left:20px;">◼</a>&emsp;Gravedad Alta
</div>

{% endmacro %}
"""

legend = branca.element.MacroElement()
legend._template = branca.element.Template(legend_html)


# Crear y añadir elementos al mapa
mapa_intervalo = folium.Map(location=[39,-0.30], zoom_start=12)
mapa_intervalo.addLayer(imagen_dNBR.sldStyle(sld_intervalos),None,'dNBR intervalos')
folium.LayerControl().add_to(mapa_intervalo)
mapa_intervalo.add_child(legend)
mapa_intervalo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c86483a5906a0eb6cc984fef9dd571c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c86483a5906a0eb6cc984fef9dd571c7&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     left: 50px;
#     width: 250px;
#     height: 250px;
#     z-index:9999;
#     font-size:14px;
#     &quot;&gt;
#     &lt;p&gt;&lt;a style=&quot;color:#ffffff;font-size:150%;margin-left:20px;&quot;&gt;◼&lt;/a&gt;&amp;emsp;Zonas No quemado
#     &lt;p&gt;&lt;a style=&quot;color:#00ff00;font-size:150%;margin-left:20px;&quot;&gt;◼&lt;/a&gt;&amp;emsp;Gravedad baja
#     &lt;p&gt;&lt;a style=&quot;color:#007f30;font-size:150%;margin-left:20px;&quot;&gt;◼&lt;/a&gt;&amp;emsp;Gravedad media baja
#     &lt;p&gt;&lt;a style=&quot;color:#FFA500;font-size:150%;margin-left:20px;&quot;&gt;◼&lt;/a&gt;&amp;emsp;Gravedad media Alta
#     &lt;p&gt;&lt;a style=&quot;color:#ff0000;font-size:150%;margin-left:20px;&quot;&gt;◼&lt;/a&gt;&amp;emsp;Gravedad Alta
# &lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c86483a5906a0eb6cc984fef9dd571c7 = L.map(
#                 &quot;map_c86483a5906a0eb6cc984fef9dd571c7&quot;,
#                 {
#                     center: [39.0, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba63cd83c1df66f51a493fa296f49c84 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ba63cd83c1df66f51a493fa296f49c84.addTo(map_c86483a5906a0eb6cc984fef9dd571c7);
#
#
#             var tile_layer_8aff2b80c64440cbb7330464d66bf80c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/49708237d87de2a00be07a24136efee3-dea53748757bef443de61813db7266a5/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8aff2b80c64440cbb7330464d66bf80c.addTo(map_c86483a5906a0eb6cc984fef9dd571c7);
#
#
#             var layer_control_a45dda6a896fa9e8cb843cd37783aecf_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ba63cd83c1df66f51a493fa296f49c84,
#                 },
#                 overlays :  {
#                     &quot;dNBR intervalos&quot; : tile_layer_8aff2b80c64440cbb7330464d66bf80c,
#                 },
#             };
#             let layer_control_a45dda6a896fa9e8cb843cd37783aecf = L.control.layers(
#                 layer_control_a45dda6a896fa9e8cb843cd37783aecf_layers.base_layers,
#                 layer_control_a45dda6a896fa9e8cb843cd37783aecf_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c86483a5906a0eb6cc984fef9dd571c7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h2><font color="blue" >Mapa Dual (DualMap) </font></h2><p>
# Este plugin nos permite en una misma ventana Html tener 2 mapas.
# Crear un mapa Dual con los 2 mapas creados en la Tarea 1 y 2

# %%
# mapa dual
mapa_dual = folium.plugins.DualMap(location=[38.9,-0.30], tiles=None, zoom_start=12)

# Mapas Base
folium.TileLayer('OpenStreetMap').add_to(mapa_dual.m1)
folium.TileLayer('CartoDB Positron').add_to(mapa_dual.m2)

# Añadir capas a visualizar
mapa_dual.m1.addLayer(NBR_pre,vis_NBR, "NBR_pre")
mapa_dual.m2.addLayer(NBR_post,vis_NBR, "NBR_post")

# Añadir control de mapas
folium.LayerControl().add_to(mapa_dual)

# Guardar mapas en web
mapa_dual.save("Medio_Ambiente.html")

mapa_dual
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34305d54900429386a7db85fc799594c {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2b4a6e49dd248d25042d7a582278c60 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 50.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/jieter/Leaflet.Sync/L.Map.Sync.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34305d54900429386a7db85fc799594c&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2b4a6e49dd248d25042d7a582278c60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34305d54900429386a7db85fc799594c = L.map(
#                 &quot;map_34305d54900429386a7db85fc799594c&quot;,
#                 {
#                     center: [38.9, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3693d958dc08d5b6324d818a153d6f39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3693d958dc08d5b6324d818a153d6f39.addTo(map_34305d54900429386a7db85fc799594c);
#
#
#             var tile_layer_7c2f6ab6031e5a6d712641b249eda0e2 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/0a415424a087273433c47f071912b8d1-9463a8176191079705a016af907b82dd/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7c2f6ab6031e5a6d712641b249eda0e2.addTo(map_34305d54900429386a7db85fc799594c);
#
#
#             var layer_control_411145c641c71dcf2a52faf5ec6e422e_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3693d958dc08d5b6324d818a153d6f39,
#                 },
#                 overlays :  {
#                     &quot;NBR_pre&quot; : tile_layer_7c2f6ab6031e5a6d712641b249eda0e2,
#                 },
#             };
#             let layer_control_411145c641c71dcf2a52faf5ec6e422e = L.control.layers(
#                 layer_control_411145c641c71dcf2a52faf5ec6e422e_layers.base_layers,
#                 layer_control_411145c641c71dcf2a52faf5ec6e422e_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_34305d54900429386a7db85fc799594c);
#
#
#
#             var map_a2b4a6e49dd248d25042d7a582278c60 = L.map(
#                 &quot;map_a2b4a6e49dd248d25042d7a582278c60&quot;,
#                 {
#                     center: [38.9, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a6f477212f9b1031d2df1b324c387fb = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a6f477212f9b1031d2df1b324c387fb.addTo(map_a2b4a6e49dd248d25042d7a582278c60);
#
#
#             var tile_layer_15b4a14f71de8c456583012c57abfed6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/373854ec40529730a94fff86b0834d9b-669d82c5e01b53b96efc151c3df357ae/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15b4a14f71d

# %% [markdown]
# <div style="border: 3px solid #00FF00; border-radius: 12px; background: #90EE90; padding: 20px; box-shadow: 2px 2px 8px rgba(0,0,0,0.15); margin-top: 25px;">
# <h2><font color="red" >TAREA 1</font></h2>
# <h3> Realizar un mapa de Indice de Vegetación ajustado al suelo (SAVI) con imágenes SENTINEL 2A de la evolución del incendio ocurrido en Montitxelvo el 2/11/2023.</h3>
#
# <h3><font color="blue" >Calcular el SAVI_pre, SAVI_post y Guardar SAVI_post como Geotiff </font></h3><p>
# <p>
# <p>El método Índice de vegetación ajustado al suelo (SAVI) es un índice de vegetación que intenta minimizar las influencias del brillo del suelo utilizando un factor de corrección de brillo del suelo. Esto con frecuencia se utiliza en regiones áridas en donde la cubierta de vegetación es baja y genera valores entre -1,0 y 1,0, siendo la vegetación sana 0 a 1.
# Su creador, Huete, agregó un factor de ajuste del suelo L a la ecuación de NDVI para corregir los efectos del ruido del suelo (color del suelo, humedad del suelo, variabilidad del suelo a través de la región, etc.), que tienden a afectar a los resultados.
# <h3><font color="blue" >Parámetros de localización</font></h3><p>
# <p>
# <ul>   <li> Fechas Pre: '2023-09-15', '2023-10-15' </li>
#        <li> Fechas Post: '2023-11-15', '2023-12-15' </li>
#        <li> Zona a Exportar: Punto mínimo: [38.8,-0.4] Punto máximo [39.0,-0.15] </li>
#        <li> Punto Central : [38.9,-0.28]     </li>
# </ul>
#
# ### L = 0.428
# ![image.png](attachment:db62bcf2-93f6-487a-8d7d-21fe583dae8d.png)
# </div>

# %%
import folium
from folium import plugins
import ee

# %%
# Colección de imágenes de Sentinel con una nubosidad inferior al 20% y la medía calculada de los pixels
sentinel_pre= (ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
                  .filterDate('2023-09-15','2023-10-15')
                  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',20)).mean()) #el filtro de nubosidad varía según imagen

sentinel_post= (ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
                  .filterDate('2023-11-15','2023-12-15')
                  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',20)).mean())

# Funciones de calculo SAVI
def SAVI(image):
    SAVI = image.expression('float((NIR-RED)/(NIR+RED+L)*(1+L))',{
        'NIR' : image.select("B8").multiply(0.0001),     # Escala según el catalogo de datos de GEE para sentinel2
        'RED' : image.select("B4").multiply(0.0001),
        'L' : 0.428
    })
    return SAVI

# Parámetros de visualización de la imágen
vis_SAVI ={
    'max': 1,
    'min': -0.1,
    # Paleta de colores standar de GEE
    'palette' : ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718','74A901', '66A000', '529400', '3E8601', '207401', '056201',
               '004C00', '023B01', '012E01', '011D01', '011301']} 

# Llamada a las funciones
SAVI_pre = SAVI(sentinel_pre)
SAVI_post = SAVI(sentinel_post)


# Exportar imagen a Google Drive. Configuración parámetros de salida
geometry = ee.Geometry.Rectangle([-0.4,38.8, -0.15, 39.0]) # Coordenadas geográficas minima (longitud, latitud) y maxima de la imagen a exportar
task_config = {
        'region': geometry,
        'fileFormat': 'GeoTIFF',
        'fileNamePrefix': 'FedorAdrian_SAVI_post',
        'folder':'gee-datos',
        'scale': 20,      # Resolución en metros del pixel, siempre la resolución más desfavorable de las bandas utilizadas 
        'crs': 'EPSG:4326',
        'image': SAVI_post,
        'description': 'Imagen procesada SAVIpost'
    }
ee.batch.Export.image.toDrive(**task_config).start()

# Crear y añadir elementos al mapa
mapa_SAVI = folium.Map(location=[38.9, -0.28], zoom_start = 11) #Las coordenadas son en Latitud y Longitud
mapa_SAVI.addLayer(SAVI_pre,vis_SAVI, "SAVI_pre")
mapa_SAVI.addLayer(SAVI_post,vis_SAVI, "SAVI_post")

folium.LayerControl().add_to(mapa_SAVI)

mapa_SAVI
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5ec47b350e7cf7e748a51b1ceacd0f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5ec47b350e7cf7e748a51b1ceacd0f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5ec47b350e7cf7e748a51b1ceacd0f7 = L.map(
#                 &quot;map_c5ec47b350e7cf7e748a51b1ceacd0f7&quot;,
#                 {
#                     center: [38.9, -0.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad190f6822d2e0770a76005f734af364 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ad190f6822d2e0770a76005f734af364.addTo(map_c5ec47b350e7cf7e748a51b1ceacd0f7);
#
#
#             var tile_layer_f8a6ef784fc487c6a864c392adf45a0c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/7ed0b7fb63527e41def3c185f63dcbc5-e890c38529fe38ac07cdea0317fe889b/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f8a6ef784fc487c6a864c392adf45a0c.addTo(map_c5ec47b350e7cf7e748a51b1ceacd0f7);
#
#
#             var tile_layer_733143f1ca3e6edd17898e81867e845f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/0ef65ca3585e178880ba4816171f198a-4c7d2c607e2e18b2fcf982f608525a0c/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_733143f1ca3e6edd17898e81867e845f.addTo(map_c5ec47b350e7cf7e748a51b1ceacd0f7);
#
#
#             var layer_control_638ef4bf58bd42c7fc40876ab464861c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ad190f6822d2e0770a76005f734af364,
#                 },
#                 overlays :  {
#                     &quot;SAVI_pre&quot; : tile_layer_f8a6ef784fc487c6a864c392adf45a0c,
#                     &quot;SAVI_post&quot; : tile_layer_733143f1ca3e6edd17898e81867e845f,
#                 },
#             };
#             let layer_control_638ef4bf58bd42c7fc40876ab464861c = L.control.layers(
#                 layer_control_638ef4bf58bd42c7fc40876ab464861c_layers.base_layers,
#                 layer_control_638ef4bf58bd42c7fc40876ab464861c_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c5ec47b350e7cf7e748a51b1ceacd0f7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <div style="border: 3px solid #00FF00; border-radius: 12px; background: #90EE90; padding: 20px; box-shadow: 2px 2px 8px rgba(0,0,0,0.15); margin-top: 25px;">
#
# <h2><font color="red" >TAREA 2</font></h2><p>
# <h3> Crear un mapa de Indice de Vegetación Mejorado (EVI) con imágenes LANDSAT 8 de la evolución del incendio anterior. <p><p>
# <font color="blue" > </font></h3>
#
# <h3><font color="blue" >Calcular el EVI_pre, EVI_post y Guardar EVI_post como Geotiff</font></h3><p>
# <p>
# <p>EVI es un índice que trabaja las bandas rojo y azul del visible para corregir simultaneamente el efecto de la atmósfera y junto al factor L corregir la influencia del suelo. Además del factor L emplea dos parámetros adicionales constantes C (C1 = 6.0, C2 = 7.5) y G = 2.5
# Los valores para EVI varían del -1 a 1, siendo la vegetación sana valores entre 0.2 y 0.8.
#
# ### L = 1.0
#
# ![image.png](attachment:31ef0655-c5ba-4e3e-9282-19bd7023f01c.png)
# </div>

# %%
# Colección de imágenes de Sentinel con una nubosidad inferior al 20% y la medía calculada de los pixels
sentinel_pre= (ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
                  .filterDate('2023-09-15','2023-10-15')
                  .filter(ee.Filter.lt('CLOUD_COVER',20)).mean()) #el filtro de nubosidad varía según imagen

sentinel_post= (ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
                  .filterDate('2023-11-15','2023-12-15')
                  .filter(ee.Filter.lt('CLOUD_COVER',20)).mean())

# Funciones de calculo SAVI
def EVI(image):
    EVI = image.expression('float(G*((NIR-RED)/(NIR+(C1*RED)-(C2*BLUE)+L)))',{
        'NIR' : image.select("SR_B5").multiply(2.75e-05),     # Escala según el catalogo de datos de GEE para sentinel2
        'RED' : image.select("SR_B4").multiply(2.75e-05),
        'BLUE': image.select("SR_B2").multiply(2.75e-05),
        'L' : 1.0,
        'G': 2.5,
        'C1': 6.0,
        'C2': 7.5
    })
    return EVI

# Parámetros de visualización de la imágen
vis_EVI ={
    'max': 1,
    'min': 0,
    # Paleta de colores standar de GEE
    'palette' : ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718','74A901', '66A000', '529400', '3E8601', '207401', '056201',
               '004C00', '023B01', '012E01', '011D01', '011301']} 

# Llamada a las funciones
EVI_pre = EVI(sentinel_pre)
EVI_post = EVI(sentinel_post)


# Exportar imagen a Google Drive. Configuración parámetros de salida
geometry = ee.Geometry.Rectangle([-0.4,38.8, -0.15, 39.0]) # Coordenadas geográficas minima (longitud, latitud) y maxima de la imagen a exportar
task_config = {
        'region': geometry,
        'fileFormat': 'GeoTIFF',
        'fileNamePrefix': 'FedorAdrian_EVI_post',
        'folder':'gee-datos',
        'scale': 20,      # Resolución en metros del pixel, siempre la resolución más desfavorable de las bandas utilizadas 
        'crs': 'EPSG:4326',
        'image': EVI_post,
        'description': 'Imagen procesada EVIpost'
    }
ee.batch.Export.image.toDrive(**task_config).start()

# Crear y añadir elementos al mapa
mapa_EVI = folium.Map(location=[38.9, -0.28], zoom_start = 11) #Las coordenadas son en Latitud y Longitud
mapa_EVI.addLayer(EVI_pre,vis_EVI, "EVI_pre")
mapa_EVI.addLayer(EVI_post,vis_EVI, "EVI_post")

folium.LayerControl().add_to(mapa_EVI)

mapa_EVI
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cce2d0583f772f4c810fe51a5028b66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cce2d0583f772f4c810fe51a5028b66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cce2d0583f772f4c810fe51a5028b66 = L.map(
#                 &quot;map_1cce2d0583f772f4c810fe51a5028b66&quot;,
#                 {
#                     center: [38.9, -0.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49c092fee1f8568086d538c56626c323 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_49c092fee1f8568086d538c56626c323.addTo(map_1cce2d0583f772f4c810fe51a5028b66);
#
#
#             var tile_layer_d7e4bd8460883ffe0a07d41c87cd9792 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/fae5b3f2456682beaafa04fb7c53755f-e046f7c127d8d0fbe6591806e5b61a51/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d7e4bd8460883ffe0a07d41c87cd9792.addTo(map_1cce2d0583f772f4c810fe51a5028b66);
#
#
#             var tile_layer_c42c5c41bdf5af4c4f7a2565fdd6c7da = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/ba05d8acece5d6e93300f87573afe85d-9701418a48b52d8d38771ee04cd5856d/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c42c5c41bdf5af4c4f7a2565fdd6c7da.addTo(map_1cce2d0583f772f4c810fe51a5028b66);
#
#
#             var layer_control_5898fe3702e2ec019764f772d906ca91_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_49c092fee1f8568086d538c56626c323,
#                 },
#                 overlays :  {
#                     &quot;EVI_pre&quot; : tile_layer_d7e4bd8460883ffe0a07d41c87cd9792,
#                     &quot;EVI_post&quot; : tile_layer_c42c5c41bdf5af4c4f7a2565fdd6c7da,
#                 },
#             };
#             let layer_control_5898fe3702e2ec019764f772d906ca91 = L.control.layers(
#                 layer_control_5898fe3702e2ec019764f772d906ca91_layers.base_layers,
#                 layer_control_5898fe3702e2ec019764f772d906ca91_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1cce2d0583f772f4c810fe51a5028b66);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <div style="border: 3px solid #00FF00; border-radius: 12px; background: #90EE90; padding: 20px; box-shadow: 2px 2px 8px rgba(0,0,0,0.15); margin-top: 25px;">
#
# <h2><font color="red" >TAREA 3</font></h2><p>
# <h3> Realizar un mapa dual con los mapas obtenidos en la Tarea 1 y 2</h3> <p>
# Salvar el mapa como:  <h4>Medio_Ambiente_'Apellidos alumnos'.html</h4>
# </div>

# %%
# mapa dual
mapa_dual = folium.plugins.DualMap(location=[38.9,-0.30], tiles=None, zoom_start=12)

# Mapas Base
folium.TileLayer('OpenStreetMap').add_to(mapa_dual.m1)
folium.TileLayer('CartoDB Positron').add_to(mapa_dual.m2)

# Añadir capas a visualizar
mapa_dual.m1.addLayer(SAVI_pre,vis_SAVI, "SAVI_pre")
mapa_dual.m2.addLayer(SAVI_post,vis_SAVI, "SAVI_post")

mapa_dual.m1.addLayer(EVI_pre,vis_EVI, "EVI_pre")
mapa_dual.m2.addLayer(EVI_post,vis_EVI, "EVI_post")

# Añadir control de mapas
folium.LayerControl().add_to(mapa_dual)

# Guardar mapas en web
mapa_dual.save("Medio_Ambiente_Tikhomirov_Jauregui.html")

mapa_dual
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee43fb12ab036046364369ecd1326161 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f1906a8cd41a11e724be8b457ae1db4 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 100.0%;
#                     left: 50.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/jieter/Leaflet.Sync/L.Map.Sync.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee43fb12ab036046364369ecd1326161&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f1906a8cd41a11e724be8b457ae1db4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee43fb12ab036046364369ecd1326161 = L.map(
#                 &quot;map_ee43fb12ab036046364369ecd1326161&quot;,
#                 {
#                     center: [38.9, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50fb68edd842a7f572487aca588edb28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_50fb68edd842a7f572487aca588edb28.addTo(map_ee43fb12ab036046364369ecd1326161);
#
#
#             var tile_layer_eb3a97afa18ed217b6954414550ecefc = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/7ed0b7fb63527e41def3c185f63dcbc5-679b0557c4729e23433d2da41da7601e/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eb3a97afa18ed217b6954414550ecefc.addTo(map_ee43fb12ab036046364369ecd1326161);
#
#
#             var tile_layer_a15979ebf3139bdf6c2cb0336671133f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/213590641016/maps/fae5b3f2456682beaafa04fb7c53755f-817acb39070eae55d78a3c54fd79bf14/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Alumno: Tecnolog\u00edas de la Informaci\u00f3n Geogr\u00e1fica&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a15979ebf3139bdf6c2cb0336671133f.addTo(map_ee43fb12ab036046364369ecd1326161);
#
#
#             var layer_control_5b7d1bac383773dbdfbeca6816e94eeb_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_50fb68edd842a7f572487aca588edb28,
#                 },
#                 overlays :  {
#                     &quot;SAVI_pre&quot; : tile_layer_eb3a97afa18ed217b6954414550ecefc,
#                     &quot;EVI_pre&quot; : tile_layer_a15979ebf3139bdf6c2cb0336671133f,
#                 },
#             };
#             let layer_control_5b7d1bac383773dbdfbeca6816e94eeb = L.control.layers(
#                 layer_control_5b7d1bac383773dbdfbeca6816e94eeb_layers.base_layers,
#                 layer_control_5b7d1bac383773dbdfbeca6816e94eeb_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_ee43fb12ab036046364369ecd1326161);
#
#
#
#             var map_2f1906a8cd41a11e724be8b457ae1db4 = L.map(
#                 &quot;map_2f1906a8cd41a11e724be8b457ae1db4&quot;,
#                 {
#                     center: [38.9, -0.3],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_734caf72bcd09cc9edb606e524313d59 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;,
